# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv #crete folder opencv in mydrive and then give path change only after mydrive and name of image saved in drive
import sys
from google.colab.patches import cv2_imshow
import os
image_path="/content/drive/MyDrive/opencv/colorimg.jpg"
if not os.path.exists(image_path):
  sys.exit(f"Error:Image file not found at{image_path}")
img=cv.imread(image_path)

if img is None:
  sys.exit("could not run image.")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x397>

# %%
from google.colab import drive
drive.mount('/content/drive')
# import the required library
import cv2
from google.colab.patches import cv2_imshow # Import cv2_imshow

# read the input image
image = cv2.imread('/content/drive/MyDrive/opencv/colorimg.jpg')

# define the alpha and beta
alpha = 1.5 # Contrast control
beta = 20 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# display the output image
cv2_imshow(adjusted)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=612x397>

# %%
from google.colab import drive
drive.mount('/content/drive')
# import the required library
import cv2
from google.colab.patches import cv2_imshow # Import cv2_imshow

# read the input image
image = cv2.imread('/content/drive/MyDrive/opencv/grayimg.jpg')

# define the alpha and beta
alpha = -2.0 # Contrast control
beta = -20 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# display the output image
cv2_imshow(adjusted)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=717x478>

# %%
import cv2 #for gauissian image
from google.colab.patches import cv2_imshow
import sys # Import sys to exit if image loading fails

# Load an image
image_path = '/content/drive/MyDrive/opencv/colorimg.jpg' # Define the image path
image = cv2.imread(image_path)

# Add a check to see if the image was loaded successfully
if image is None:
    sys.exit(f"Error: Could not read the image from {image_path}")


# Apply Gaussian blur with specific sigma values
# A symmetrical blur (sigmaX=3, sigmaY=3 implicitly)
blurred_image_1 = cv2.GaussianBlur(image, (5, 5), 3)#giving odd no is accepted no even no are accepted it gives error for even no

# Anisotropic blur (more blur in X than Y)
blurred_image_2 = cv2.GaussianBlur(image, (5, 5), 5, 1)

# Display the images (optional)
cv2_imshow(image)
cv2_imshow(blurred_image_1)
cv2_imshow(blurred_image_2)
# cv2.waitKey(0) # waitKey and destroyAllWindows are not needed with cv2_imshow
# cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import drive #median feature use saltnoise image
drive.mount('/content/drive')
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/opencv/saltnoise.jpg')

median = cv2.medianBlur(img,3)

# Display original and blurred images using cv2_imshow
cv2_imshow(img)
cv2_imshow(median)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
import cv2 as cv
import sys
from google.colab.patches import cv2_imshow
import os
image_path="/content/drive/MyDrive/opencv/grayimg.jpg"
if not os.path.exists(image_path):
  sys.exit(f"Error:Image file not found at{image_path}")
img=cv.imread(image_path)

if img is None:
  sys.exit("could not run image.")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=717x478>
